# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Elena" # Write your name between the parenthesis
student_id = 12345678 # Change your student ID here
date_returned = "4.3.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
# Your code starts here
x = np.arange(-10,10,0.001)
y = mx.lab_1_problem_1(x, student_id)

fig,ax = plt.subplots()
ax.plot(x,y)
plt.title("First function for student 2600210")
plt.xlabel('x', size = 20)
plt.ylabel('y', size = 20)
#plt.axhline(y = 1, color = 'red', linestyle = '--')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
# Your code starts here
x = np.arange(-10,10,0.001)
y = mx.lab_1_problem_1(x, student_id)

fig,ax1 = plt.subplots()
ax1.plot(x,y, color = "green")
plt.title("Zoomed point 1")
plt.grid(True)
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(5.0373, 1, "ro")
plt.ylim(0.95,1.03)
plt.xlim(5.035,5.04)

fig,ax2 = plt.subplots()
ax2.plot(x,y, color = "blue")
plt.title("Zoomed point 2")
plt.grid(True)
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(7.41926,1, "ro")
plt.ylim(0.99,1.01)
plt.xlim(7.41,7.42)
plt.show()
